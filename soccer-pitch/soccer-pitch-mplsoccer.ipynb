# %%
from mplsoccer import Pitch, VerticalPitch

# %%
pitch = Pitch()

fig, ax = pitch.draw()

# %%
vertical_pitch = VerticalPitch()

fig, ax = vertical_pitch.draw()

# %%
pitch = Pitch()

fig, ax = pitch.grid(nrows=3, ncols=2)

# %%
pitch = Pitch(half=True)

fig, ax = pitch.draw()
